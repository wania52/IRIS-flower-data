# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt


from warnings import filterwarnings
filterwarnings(action='ignore')

# %% [markdown]
# Load the dataset

# %%
df = pd.read_csv('G:\\iris\\iris.data', header= None)

# %%
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
# Define column names
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# Assign column names to the DataFrame
df.columns = column_names

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
null = df.isnull().sum()
print("Columns with null values:")
print(null[null > 0])
# Out:
# Columns with null values:
# Series([], dtype: int64)

# %%
# Check for null values in the entire DataFrame
total_null_values = df.isnull().sum().sum()

# Display total null values
print("Total null values in DataFrame:", total_null_values)
# Out:
# Total null values in DataFrame: 0

# %%
print(df.shape)
# Out:
# (150, 5)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
df.head(150)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.tail(100)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 52            6.9          3.1           4.9          1.5  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 145           6.7          3.0           5.2          2.3   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica
# 147           6.5          3.0           5.2          2.0   Iris-virginica
# 148           6.2          3.4           5.4          2.3   Iris-virginica
# 149           5.9          3.0           5.1          1.8   Iris-virginica
#
# [100 rows x 5 columns]

# %%
species_counts = df['species'].value_counts()
# Display the count of instances of "Iris-versicolor"
print("Number of instances of Iris-versicolor:", species_counts['Iris-versicolor'])
# Out:
# Number of instances of Iris-versicolor: 50

# %%
species_counts = df['species'].value_counts()
# Display the count of instances of "Iris-virgini"
print("Number of instances of Iris-virginica:", species_counts['Iris-virginica'])
# Out:
# Number of instances of Iris-virginica: 50

# %%
species_counts = df['species'].value_counts()
# Display the count of instances of "Iris-setosa"
print("Number of instances of Iris-setosa:", species_counts['Iris-setosa'])
# Out:
# Number of instances of Iris-setosa: 50

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
l = ['Iris-versicolor', 'Iris-setosa', 'Iris-virginica']
s = [50,50,50]
ax.pie(s, labels = l,autopct='%1.2f%%')
plt.show()

# %%
#Checking for outliars
import matplotlib.pyplot as plt
plt.figure(1)
plt.boxplot([df['sepal_length']])
plt.figure(2)
plt.boxplot([df['sepal_width']])
plt.show()

# %%
df.hist()
plt.show()

# %%
df.plot(kind ='density',subplots = True, layout =(3,3),sharex = False)
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>]], dtype=object)

# %%
df.plot(kind ='box',subplots = True, layout =(2,5),sharex = False)
# Out:
# sepal_length       Axes(0.125,0.53;0.133621x0.35)
# sepal_width     Axes(0.285345,0.53;0.133621x0.35)
# petal_length     Axes(0.44569,0.53;0.133621x0.35)
# petal_width     Axes(0.606034,0.53;0.133621x0.35)
# dtype: object

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='species',y='petal_length',data=df)
plt.subplot(2,2,2)
sns.violinplot(x='species',y='petal_width',data=df)
plt.subplot(2,2,3)
sns.violinplot(x='species',y='sepal_length',data=df)
plt.subplot(2,2,4)
sns.violinplot(x='species',y='sepal_width',data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.pairplot(df,hue='species');

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'species' is the non-numeric column that needs to be excluded
numeric_columns = df.select_dtypes(include=['number']) # Select only numeric columns

fig = plt.gcf()
fig.set_size_inches(10, 7)
fig = sns.heatmap(numeric_columns.corr(), annot=True, cmap='cubehelix', linewidths=1, linecolor='k', square=True, mask=False, vmin=-1, vmax=1, cbar_kws={"orientation": "vertical"}, cbar=True)

# %%
X = df['sepal_length'].values.reshape(-1,1)
print(X)
# Out:
# [[5.1]
#  [4.9]
#  [4.7]
#  [4.6]
#  [5. ]
#  [5.4]
#  [4.6]
#  [5. ]
#  [4.4]
#  [4.9]
#  [5.4]
#  [4.8]
#  [4.8]
#  [4.3]
#  [5.8]
#  [5.7]
#  [5.4]
#  [5.1]
#  [5.7]
#  [5.1]
#  [5.4]
#  [5.1]
#  [4.6]
#  [5.1]
#  [4.8]
#  [5. ]
#  [5. ]
#  [5.2]
#  [5.2]
#  [4.7]
#  [4.8]
#  [5.4]
#  [5.2]
#  [5.5]
#  [4.9]
#  [5. ]
#  [5.5]
#  [4.9]
#  [4.4]
#  [5.1]
#  [5. ]
#  [4.5]
#  [4.4]
#  [5. ]
#  [5.1]
#  [4.8]
#  [5.1]
#  [4.6]
#  [5.3]
#  [5. ]
#  [7. ]
#  [6.4]
#  [6.9]
#  [5.5]
#  [6.5]
#  [5.7]
#  [6.3]
#  [4.9]
#  [6.6]
#  [5.2]
#  [5. ]
#  [5.9]
#  [6. ]
#  [6.1]
#  [5.6]
#  [6.7]
#  [5.6]
#  [5.8]
#  [6.2]
#  [5.6]
#  [5.9]
#  [6.1]
#  [6.3]
#  [6.1]
#  [6.4]
#  [6.6]
#  [6.8]
#  [6.7]
#  [6. ]
#  [5.7]
#  [5.5]
#  [5.5]
#  [5.8]
#  [6. ]
#  [5.4]
#  [6. ]
#  [6.7]
#  [6.3]
#  [5.6]
#  [5.5]
#  [5.5]
#  [6.1]
#  [5.8]
#  [5. ]
#  [5.6]
#  [5.7]
#  [5.7]
#  [6.2]
#  [5.1]
#  [5.7]
#  [6.3]
#  [5.8]
#  [7.1]
#  [6.3]
#  [6.5]
#  [7.6]
#  [4.9]
#  [7.3]
#  [6.7]
#  [7.2]
#  [6.5]
# ...

# %%
Y = df['sepal_width'].values.reshape(-1,1)
print(Y)
# Out:
# [[3.5]
#  [3. ]
#  [3.2]
#  [3.1]
#  [3.6]
#  [3.9]
#  [3.4]
#  [3.4]
#  [2.9]
#  [3.1]
#  [3.7]
#  [3.4]
#  [3. ]
#  [3. ]
#  [4. ]
#  [4.4]
#  [3.9]
#  [3.5]
#  [3.8]
#  [3.8]
#  [3.4]
#  [3.7]
#  [3.6]
#  [3.3]
#  [3.4]
#  [3. ]
#  [3.4]
#  [3.5]
#  [3.4]
#  [3.2]
#  [3.1]
#  [3.4]
#  [4.1]
#  [4.2]
#  [3.1]
#  [3.2]
#  [3.5]
#  [3.1]
#  [3. ]
#  [3.4]
#  [3.5]
#  [2.3]
#  [3.2]
#  [3.5]
#  [3.8]
#  [3. ]
#  [3.8]
#  [3.2]
#  [3.7]
#  [3.3]
#  [3.2]
#  [3.2]
#  [3.1]
#  [2.3]
#  [2.8]
#  [2.8]
#  [3.3]
#  [2.4]
#  [2.9]
#  [2.7]
#  [2. ]
#  [3. ]
#  [2.2]
#  [2.9]
#  [2.9]
#  [3.1]
#  [3. ]
#  [2.7]
#  [2.2]
#  [2.5]
#  [3.2]
#  [2.8]
#  [2.5]
#  [2.8]
#  [2.9]
#  [3. ]
#  [2.8]
#  [3. ]
#  [2.9]
#  [2.6]
#  [2.4]
#  [2.4]
#  [2.7]
#  [2.7]
#  [3. ]
#  [3.4]
#  [3.1]
#  [2.3]
#  [3. ]
#  [2.5]
#  [2.6]
#  [3. ]
#  [2.6]
#  [2.3]
#  [2.7]
#  [3. ]
#  [2.9]
#  [2.9]
#  [2.5]
#  [2.8]
#  [3.3]
#  [2.7]
#  [3. ]
#  [2.9]
#  [3. ]
#  [3. ]
#  [2.5]
#  [2.9]
#  [2.5]
#  [3.6]
#  [3.2]
# ...

# %%
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.scatter(X,Y,color='b')
plt.show()

# %%
# Assuming 'species' is the non-numeric column that needs to be excluded
numeric_columns = df.select_dtypes(include=['number']) # Select only numeric columns

# Calculate correlation matrix for numeric columns
corr_mat = numeric_columns.corr()

print(corr_mat)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, test_size = 0.25)
print(train.shape)
print(test.shape)
# Out:
# (112, 5)
# (38, 5)

# %%
X_train = train[['sepal_length', 'sepal_width', 'petal_length',
                 'petal_width']]
y_train = train.species

X_test = test[['sepal_length', 'sepal_width', 'petal_length',
                 'petal_width']]
y_test = test.species

# %%
X_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 126           6.2          2.8           4.8          1.8
# 146           6.3          2.5           5.0          1.9
# 40            5.0          3.5           1.3          0.3
# 107           7.3          2.9           6.3          1.8
# 9             4.9          3.1           1.5          0.1

# %%
y_train.head()
# Out:
# 126    Iris-virginica
# 146    Iris-virginica
# 40        Iris-setosa
# 107    Iris-virginica
# 9         Iris-setosa
# Name: species, dtype: object

# %% [markdown]
# Logistic Regression model

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print("Logistic Regression Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Logistic Regression Accuracy: 0.9210526315789473

# %%
# Convert target labels to numerical encoding
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
# Convert target labels to one-hot encoding
y_train_categorical = to_categorical(y_train_encoded)
y_test_categorical = to_categorical(y_test_encoded)

# %%
# Convert target labels to numerical encoding
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
# Convert target labels to one-hot encoding
y_train_categorical = to_categorical(y_train_encoded)
y_test_categorical = to_categorical(y_test_encoded)

# %%
# Define the architecture of the model
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))  # 3 output neurons for 3 classes

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train_categorical, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.1973 - loss: 1.0535 - val_accuracy: 0.2174 - val_loss: 1.0422
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3863 - loss: 0.9519 - val_accuracy: 0.2174 - val_loss: 1.0201
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3316 - loss: 0.9342 - val_accuracy: 0.2174 - val_loss: 0.9515
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5175 - loss: 0.8512 - val_accuracy: 0.6522 - val_loss: 0.8916
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6474 - loss: 0.8073 - val_accuracy: 0.6522 - val_loss: 0.8336
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6764 - loss: 0.7852 - val_accuracy: 0.6522 - val_loss: 0.7786
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7038 - loss: 0.7302 - val_accuracy: 0.6522 - val_loss: 0.7470
# Epoch 8/50
# ...

# %%
train_loss, train_acc = model.evaluate(X_train, y_train_categorical)
print('Train accuracy', train_acc)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9705 - loss: 0.1709
# Train accuracy 0.9732142686843872

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test_categorical)
print('Test accuracy:', test_acc)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9720 - loss: 0.2148
# Test accuracy: 0.9736841917037964
